# %%
from bs4 import BeautifulSoup
import nltk, re, pymorphy2
from nltk.corpus import stopwords
russian_stopwords = stopwords.words("russian")
morph = pymorphy2.MorphAnalyzer()

# %%
pages = []

i = 1
while True:
    try:
        with open(f"p{i}.html", "r", encoding="utf-8") as f:
            pages.append(f.read())
        i += 1
    except FileNotFoundError:
        break

# %%
def extract_data(page, reviews=[]):

    page_soup = BeautifulSoup(page, "html.parser")
    
    for container in page_soup.find_all("div", {"class": "ow-opinion ow-opinions__item", "data-role": "opinion"}) + page_soup.find_all("div", {"class": "ow-opinion ow-opinion_popular ow-opinions__item", "data-role": "opinion"}):
        
        stars = len(container.find_all("span", {"class": "star-rating__star", "data-state": "selected"}))
        
        text_chunks = container.find_all("div", {"class": "ow-opinion__text-desc"})
        
        texts = []
        for i in range(len(text_chunks)):
            
            stroki = []
            for stroka in text_chunks[i].find_all("p"):
                stroki.append(stroka.text)
            
            text_chunks[i] = "\n".join(stroki)
            if not text_chunks[i] in ("{{Достоинства}}", "{{Недостатки}}", "{{Комментарий}}"):
                texts.append(text_chunks[i])
                
        texts = "\n".join(texts)
        
        if len(texts) > 10:
            reviews.append({"text": texts, "rating": stars})
    return reviews

# %%
reviews = []

for page in pages:
    reviews = extract_data(page, reviews)
    
print(len(reviews))
#print(reviews)
# Out:
# 215

# %%
def tokenize_review(review):
    tokens = nltk.word_tokenize(review["text"])
    review["tokens"] = []
    
    for token in tokens:
        if re.search("[А-Яа-яЁё]", token) is not None:
            review["tokens"].append(token.strip("-"))
    
    return review

def lemmatize_review(review):
    for i in range(len(review["tokens"])):
        review["tokens"][i] = morph.parse(review["tokens"][i])[0].normal_form
    
    filtered_tokens = []
    for i in range(len(review["tokens"])):
        if review["tokens"][i] not in russian_stopwords:
            filtered_tokens.append(review["tokens"][i])
    
    review["tokens"] = filtered_tokens
    
    return review

def preedit(review):
    review = tokenize_review(review)
    review = lemmatize_review(review)
    return review

# %%
for i in range(len(reviews)):
    reviews[i] = preedit(reviews[i])
    
print(reviews)
# Out:
# [{'text': 'Цена = качество\nПока не поняла, если они за такую цену\nВыбирала в этом ценовом сегменте, остановилась на этих из-за положительных отзывов. Купила не для частого прослушивания, например, пока в автобусе едешь или голосовое смс прослушать, вот. Для этого наушники в самый раз. Заодно купила оригинальный чехол, удобно, мне нравится.', 'rating': 10, 'tokens': ['цена', 'качество', 'пока', 'понять', 'цена', 'выбирать', 'это', 'ценовый', 'сегмент', 'остановиться', 'из-за', 'положительный', 'отзыв', 'купить', 'частый', 'прослушивание', 'например', 'пока', 'автобус', 'ехать', 'голосовой', 'смс', 'прослушать', 'это', 'наушник', 'самый', 'заодно', 'купить', 'оригинальный', 'чехол', 'удобно', 'нравиться']}, {'text': 'Коробка была в пленке, однако попытка зарядить наушники завершилась неудачей, кейс не реагирует никак. Пойду сдавать по гарантии.', 'rating': 2, 'tokens': ['коробка', 'плёнка', 'однако', 'попытка', 'зарядить', 'наушник', 'завершиться', 'неудача', 'кейс', 'реагировать', 'никак', 'пойти', 'сдавать', 'гарантия']}, {'text': '- Дизайн\n- Удобство\n- Надёжность\n- Можно долго перечислять.\n- Незначительно царапается кейс\n- Крышка со временем расшатывается, в моём случае скорее всего из-за неаккуратного пользования.\nКидали об стену - Выжили, топили в стиралке - Выжили, Иногда разряжались буквально в ноль - Выжили, при этом роняли, кидали со всей силы об стену без чехла, после этого никаких последствий не обнаружили, единственное - после утопления правого наушника немного притих, спустя неделю этот эффект исчез и наушник полностью работает как с завода.', 'rating': 10, 'tokens': ['дизайн', 'удобство', 'надёжность', 'долго', 'перечислять', 'незначительно', 'царапаться', 'кейс', 'крышка', 'время', 'расшатываться', 'случай', 'скорее', 'весь', 'из-за', 'неаккуратный', 'пользование', 'кидать', 'стена', 'выжить', 'топить', 'стиралка', 'выжить', 'разряжаться', 'буквально', 'ноль', 'выжить', 'это', 'ронять', 'кидать', 'весь', 'сила', 'стена', 'чехол', 'это', 'никакой', 'последствие', 'обнаружить', 'единственный', 'утопление', 'правый', 'наушник', 'немного', 'притихнуть', 'спустя', 'неделя', 'эффект', 'исчезнуть', 'наушник', 'полностью', 'работать', 'завод']}, {'text': 'Удобно носить с собой\nХороший звук\nПрекрасен бас\nРаз в пол года происходит дисконект блюпупа\nА так нареканий 0\nПользуюсь очень давно, купил на старте продаж, дабы не зацарапать кейс, взял чехол от эйрподс 2,все стало прекрасно, помыл почистил и в путь, в метро самое то ездить, да и плотно сидят в ушах, при беге держатся плотно\nСоветую данный продукт, за свои деньги лучшие\nP. S. Брал за 1890', 'rating': 10, 'tokens': ['удобно', 'носить', 'хороший', 'звук', 'прекрасный', 'бас', 'пол', 'год', 'происходить', 'дисконект', 'блюпуп', 'нарекание', 'пользоваться', 'очень', 'давно', 'купить', 'старт', 'продажа', 'дабы', 'зацарапать', 'кейс', 'взять', 'чехол', 'эйрподс', 'всё', 'стать', 'прекрасно', 'помыть', 'почистить', 'путь', 'метро', 'самый', 'ездить', 'плотно', 'сидеть', 'ухо', 'бег', 'держаться', 'плотно', 'советовать', 'данный', 'продукт', 'свой', 'деньга', 'хороший', 'брать']}, {'text': 'Хороший звук из коробки, но поиграв с эквалайзером будет ещё лучше!\nВнешний вид хорош собой.\nДля меня очень удобные, но использую уже самые большие амбушурки, т.к заядлый меломан )\nРадиус действия, как по мне, больше 10 метров! об этом в комментариях.\nПравый наушник стал играть тише, на следующий день стал играть на столько тихо, что вообще не слышно.\nзвучали месяцев 5 и по гарантии обменял. Взял точно такие и не жалею!\nНа работе телефон лежал в боксе(Огромный гараж для спец техники)\nи ушёл метров на 15 миниму. Звук передавало через такое расстояние, но с небольшими разрывами в пару миллисекунд.', 'rating': 10, 'tokens': ['хороший', 'звук', 'коробка', 'поиграть', 'эквалайзер', 'ещё', 'хороший', 'внешний', 'вид', 'хороший', 'очень', 'удобный', 'использовать', 'самый', 'больший', 'амбушурка', 'т.к', 'заядлый', 'меломан', 'радиус', 'действие', 'большой', 'метр', 'это', ' ...

# %%
def make_freq_dict(reviews, min):
    all_tokens = {}
    for review in reviews:
        for token in review["tokens"]:
            if token in all_tokens:
                all_tokens[token].append(review["rating"])
            else:
                all_tokens[token] = [review["rating"]]
    
    popular_tokens = {}
    for token in all_tokens:
        if len(all_tokens[token]) >= min:
            all_tokens[token].sort()
            popular_tokens[token] = all_tokens[token]
    
    return popular_tokens

popular_tokens = make_freq_dict(reviews, min=4)
popular_tokens
# Out:
# {'цена': [2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'качество': [2,
#   2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'пока': [2,
#   2,
#   4,
#   4,
#   4,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'понять': [4, 6, 6, 8, 10, 10],
#  'выбирать': [8, 8, 10, 10, 10, 10, 10, 10],
#  'это': [2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'из-за': [2, 4, 6, 6, 8, 8, 8, 8, 8, 10, 10, 10, 10],
#  'отзыв': [2, 4, 6, 8, 10, 10, 10, 10, 10, 10],
#  'купить': [2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   6,
#   6,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'прослушивание': [2, 4, 4, 4, 8, 8, 8, 10, 10, 10, 10],
#  'наушник': [2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'самый': [2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'удобно': [6, 8, 8, 8, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10],
#  'нравиться': [10, 10, 10, 10],
#  'коробка': [2, 4, 6, 6, 10],
#  'кейс': [2, 6, 10, 10, 10, 10, 10, 10],
#  'никак': [2, 4, 4, 8, 8, 10],
#  'пойти': [2, 2, 2, 6, 6, 8, 10, 10, 10, 10],
#  'гарантия': [2, 4, 6, 8, 8, 8, 10],
#  'дизайн': [2,
#   2,
#   2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   6,
#   6,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'удобство': [6, 8, 10, 10, 10, 10],
#  'долго': [4, 6, 6, 6, 8, 10, 10, 10, 10, 10, 10, 10, 10],
#  'время': [4,
#   4,
#   6,
#   6,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'случай': [4, 4, 4, 4, 8, 8, 10, 10],
#  'весь': [2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'стена': [10, 10, 10, 10],
#  'никакой': [2, 2, 2, 4, 4, 10, 10, 10, 10],
#  'обнаружить': [10, 10, 10, 10, 10],
#  'единственный': [10, 10, 10, 10, 10],
#  'правый': [2, 2, 2, 2, 2, 4, 4, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 10, 10, 10],
#  'немного': [4, 8, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10],
#  'спустя': [2, 4, 4, 4, 6, 8, 8, 8, 8, 10, 10],
#  'неделя': [2, 2, 2, 8, 8, 10, 10, 10],
#  'эффект': [4, 10, 10, 10, 10, 10],
#  'полностью': [4, 4, 6, 8, 8, 8, 8, 8, 10, 10, 10, 10, 10],
#  'работать': [2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'хороший': [2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'звук': [2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'прекрасный': [8, 10, 10, 10, 10],
#  'бас': [2, 4, 4, 4, 6, 8, 8, 8, 8, 8, 10, 10, 10, 10, 10, 10],
#  'пол': [4, 8, 10, 10],
#  'год': [2,
#   4,
#   6,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'пользоваться': [4, 4, 4, 6, 6, 8, 8, 8, 8, 10, 10, 10, 10, 10],
#  'очень': [2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'взять': [2, 2, 2, 2, 2, 4, 4, 6, 6, 6, 6, 8, 8, 10, 10, 10, 10, 10, 10],
#  'всё': [2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'стать': [2,
#   4,
#   4,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'плотно': [2, 8, 8, 10, 10, 10, 10, 10],
#  'сидеть': [4,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'ухо': [2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'держаться': [4, 4, 4, 4, 4, 4, 6, 8, 8, 10, 10, 10],
#  'советовать': [2, 2, 4, 4, 4, 4, 4, 4, 6, 6, 8, 8, 8, 10, 10, 10],
#  'данный': [2, 4, 4, 6, 6, 10],
#  'свой': [2,
#   2,
#   2,
#   4,
#   4,
#   6,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'деньга': [2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   4,
#   4,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'брать': [2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   6,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'эквалайзер': [6, 8, 8, 8, 8, 8, 8, 10, 10, 10, 10, 10],
#  'ещё': [2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'внешний': [2, 2, 4, 4, 4, 6, 6, 8, 8, 8, 8, 10, 10],
#  'вид': [2, 2, 2, 2, 4, 4, 6, 6, 6, 8, 8, 8, 10, 10],
#  'удобный': [2,
#   2,
#   4,
#   4,
#   4,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'использовать': [2,
#   2,
#   2,
#   6,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'больший': [2, 6, 8, 8, 10, 10, 10, 10, 10, 10, 10, 10],
#  'т.к': [2, 2, 4, 4, 8, 10, 10, 10, 10],
#  'меломан': [6, 10, 10, 10],
#  'большой': [4, 4, 4, 6, 6, 6, 8, 8, 8, 10, 10, 10, 10, 10, 10],
#  'комментарий': [8, 10, 10, 10],
#  'играть': [2, 2, 4, 4, 4, 8, 8, 8, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10],
#  'тихий': [2, 2, 2, 2, 4, 4, 4, 4, 6, 10, 10, 10, 10],
#  'следующий': [2, 4, 6, 10, 10],
#  'день': [2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   6,
#   6,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'вообще': [2,
#   2,
#   2,
#   2,
#   4,
#   4,
#   6,
#   6,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'слышный': [2, 2, 4, 4, 4, 6, 8, 8, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10],
#  'звучать': [4, 4, 4, 6, 6, 6, 8, 8, 8, 10, 10, 10, 10, 10, 10, 10],
#  'месяц': [2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'точно': [2, 6, 8, 10, 10, 10],
#  'работа': [2, 2, 2, 4, 8, 8, 10, 10, 10, 10, 10, 10],
#  'телефон': [2, 4, 4, 4, 4, 4, 6, 6, 6, 8, 8, 8, 10, 10, 10, 10, 10, 10, 10],
#  'огромный': [4, 4, 8, 10],
#  'передавать': [10, 10, 10, 10],
#  'расстояние': [2, 2, 6, 10, 10, 10],
#  'небольшой': [2, 2, 4, 6, 8, 10, 10, 10, 10, 10, 10],
#  'пара': [6, 6, 8, 8, 8, 10, 10],
#  'отличный': [4,
#   4,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'держать': [4, 6, 8, 8, 10, 10, 10, 10, 10, 10, 10, 10, 10],
#  'заряд': [2, 4, 4, 6, 6, 10, 10, 10, 10, 10, 10, 10, 10, 10],
#  'зарядка': [2, 4, 4, 6, 10, 10, 10],
#  'форма': [8, 8, 8, 10, 10],
#  'вполне': [8, 8, 8, 10, 10, 10, 10],
#  'разный': [4, 4, 4, 4, 8, 8, 10, 10, 10],
#  'приятный': [4, 8, 10, 10, 10, 10, 10],
#  'быстро': [2, 4, 4, 10, 10, 10, 10],
#  'просто': [2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'нету': [2, 10, 10, 10, 10],
#  'глянцевый': [8, 10, 10, 10],
#  'пластик': [2, 6, 6, 6, 8, 8, 8, 10, 10, 10],
#  'мочь': [2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'легко': [4, 4, 6, 8, 10, 10, 10, 10],
#  'отнести': [2, 4, 8, 10, 10, 10],
#  'недостаток': [2, 4, 4, 4, 6, 8, 8, 10, 10, 10, 10, 10, 10, 10, 10, 10],
#  'общий': [4, 4, 4, 8, 8, 10, 10, 10, 10],
#  'разговор': [10, 10, 10, 10],
#  'шум': [2, 4, 4, 4, 4, 6, 8, 8, 10, 10, 10, 10, 10, 10],
#  'проблема': [2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'любой': [4, 4, 6, 10, 10, 10],
#  'устройство': [4, 4, 6, 8, 8, 8, 8],
#  'пк': [4, 4, 4, 6, 6, 6, 8, 8, 8, 10, 10, 10],
#  'дешёвый': [2, 2, 4, 4, 4, 4, 6, 6, 6, 6, 8, 10, 10],
#  'блютуз': [4, 4, 6, 6, 8, 10, 10],
#  'слушать': [2, 4, 6, 6, 6, 6, 6, 8, 8, 8, 10, 10, 10, 10, 10, 10, 10],
#  'попробовать': [2, 2, 6, 8],
#  'амбушюр': [2,
#   2,
#   4,
#   4,
#   4,
#   6,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'приходиться': [2, 6, 6, 6, 6, 8, 8, 8, 10],
#  'использование': [2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'нормальный': [2, 2, 4, 4, 6, 6, 10, 10, 10, 10, 10, 10],
#  'компьютер': [4, 6, 8, 8, 10, 10],
#  'тысяча': [2, 2, 2, 4, 6, 10, 10],
#  'рубль': [2, 4, 4, 6, 10],
#  'вернуть': [2, 2, 2, 2, 4, 6, 6, 8],
#  'магазин': [2, 2, 4, 4, 4, 6, 8, 8, 10, 10],
#  'сломаться': [2, 2, 2, 4, 4, 4, 4, 6, 6, 8, 8, 8, 10, 10, 10],
#  'аккумулятор': [4, 4, 6, 10, 10, 10],
#  'звучание': [2, 4, 6, 6, 8, 8, 10, 10, 10],
#  'около': [2, 2, 4, 6, 8, 10, 10, 10],
#  'динамика': [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4, 6, 6, 8, 10, 10, 10],
#  'дорогой': [2, 2, 2, 2, 2, 2, 6, 6, 8, 8, 10, 10, 10, 10, 10, 10, 10],
#  'стоить': [2, 2, 2, 4, 4, 4, 6, 6, 8, 8, 10, 10, 10, 10, 10],
#  'высокий': [2, 6, 8, 8, 8, 8, 8, 8, 8, 10, 10, 10],
#  'частота': [4, 4, 6, 6, 8, 8, 8, 8, 10],
#  'остальной': [2, 4, 6, 8, 10, 10],
#  'достаточно': [4, 4, 4, 8, 8, 10, 10, 10, 10],
#  'чистый': [6, 8, 8, 8, 10, 10, 10, 10, 10, 10, 10, 10, 10],
#  'особенно': [6, 8, 10, 10, 10, 10],
#  'сравнивать': [8, 8, 10, 10],
#  'басс': [10, 10, 10, 10, 10],
#  'хватать': [10, 10, 10, 10],
#  'разъём': [2, 2, 2, 2, 4, 6, 10, 10, 10, 10, 10],
#  'микрофон': [2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'бочка': [2, 2, 8, 10, 10],
#  'ветер': [2, 4, 10, 10],
#  'плохо': [2, 2, 4, 4, 4, 4, 10],
#  'найти': [2, 2, 2, 2, 2, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10],
#  'целое': [2, 6, 6, 6, 8, 8, 8, 8, 10, 10, 10, 10],
#  'довольный': [10, 10, 10, 10, 10, 10, 10, 10, 10],
#  'который': [2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'плохой': [2, 2, 4, 4, 6, 6, 6, 8, 8, 10, 10, 10, 10, 10, 10, 10, 10, 10],
#  'красивый': [2, 4, 4, 4, 4, 4, 6, 8, 10, 10],
#  'управление': [2, 6, 10, 10, 10, 10, 10],
#  'час': [2,
#   2,
#   4,
#   4,
#   4,
#   6,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'полный': [2, 2, 2, 4, 4, 8, 10, 10, 10],
#  'громкость': [2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'хлипкий': [2, 4, 4, 6, 6, 10],
#  'рекомендовать': [2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'покупка': [4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'микро': [2, 2, 4, 4, 4, 6, 6, 6, 8, 8, 10, 10, 10, 10],
#  'начать': [2, 2, 2, 6, 6, 8],
#  'вариант': [8, 8, 10, 10, 10],
#  'неплохо': [6, 6, 8, 8, 8, 10, 10],
#  'ужасный': [2, 2, 2, 2, 2, 4, 4, 4, 8, 8],
#  'невозможно': [2, 4, 6, 8, 10],
#  'качественный': [2, 4, 4, 6, 6, 10, 10, 10, 10, 10],
#  'стоимость': [2, 2, 4, 4, 8, 8],
#  'модель': [2, 4, 4, 6, 8, 8, 8, 8, 10],
#  'жёсткий': [4, 4, 4, 6, 8, 8, 8],
#  'фон': [4, 8, 8, 10],
#  'подключить': [4, 4, 8, 10, 10],
#  'уровень': [4, 6, 8, 10, 10],
#  'вес': [2, 2, 4, 4, 4, 6, 6, 6, 8, 10, 10],
#  'радио': [4, 10, 10, 10],
#  'динамик': [2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10],
#  'отваливаться': [2, 2, 2, 4, 10, 10],
#  'встроить': [4, 4, 6, 8, 10, 10, 10, 10],
#  'оплётка': [6, 6, 6, 8, 8, 8, 8, 8, 10, 10],
#  'кабель': [4, 4, 4, 4, 6, 6, 6, 8, 8, 8, 8, 8, 10, 10, 10, 10],
#  'тканевый': [6, 8, 8, 8, 10],
#  'итог': [2, 2, 4, 6, 8, 8, 10],
#  'чашка': [4, 4, 4, 8, 8, 8, 8],
#  'левый': [2, 2, 2, 2, 2, 4, 4, 4, 6, 6, 6, 8, 8, 8, 8, 8, 8, 10, 10],
#  'право': [2, 2, 4, 4, 8, 8, 8, 8, 8, 10],
#  'болтаться': [4, 4, 4, 4, 8, 10],
#  'голова': [2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'постоянно': [2, 2, 2, 2, 6, 6, 6, 8, 10, 10],
#  'несколько': [2, 2, 10, 10, 10, 10, 10],
#  'назад': [2, 2, 10, 10],
#  'поменять': [2, 2, 2, 6, 6, 8],
#  'брак': [2, 2, 2, 4, 6],
#  'менять': [2, 2, 2, 2, 10],
#  'интересный': [2, 4, 4, 10, 10, 10, 10],
#  'довольно': [2, 4, 4, 4, 6, 6, 8, 8, 8, 10, 10],
#  'громкий': [2, 2, 2, 2, 6, 6, 6, 8, 8, 8, 10, 10, 10],
#  'контакт': [6, 6, 8, 8, 8, 8, 10],
#  'покупатель': [6, 10, 10, 10],
#  'вопреки': [8, 8, 8, 8],
#  'клевета': [8, 8, 8, 8],
#  'хейтер': [8, 8, 8, 8],
#  'причём': [2, 8, 8, 8, 10],
#  'винд': [2, 2, 8, 8, 10],
#  'объёмный': [4, 6, 8, 8, 8, 10],
#  'басовитый': [8, 8, 8, 8],
#  'половина': [4, 8, 8, 8, 10],
#  'новый': [6, 6, 8, 8, 8, 8, 10, 10],
#  'провод': [2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   6,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'ободок': [2, 4, 8, 8, 8],
#  'крепление': [2, 2, 4, 6, 6, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 10, 10],
#  'развалиться': [2, 2, 8, 8, 8, 8],
#  'комфортно': [8, 8, 8, 8, 10, 10],
#  'внутри': [4, 6, 8, 8, 8, 8],
#  'возможно': [4, 4, 4, 6, 8, 8, 8, 8, 8, 10],
#  'давление': [8, 8, 8, 8, 10, 10, 10],
#  'рука': [4, 8, 8, 8, 8, 8, 8, 10],
#  'крутить': [2, 2, 6, 8, 8, 10],
#  'регулировка': [2, 4, 6, 6, 8, 8, 10, 10, 10, 10, 10, 10, 10],
#  'максимальный': [2, 2, 2, 2, 4, 8, 8, 10, 10],
#  'пульт': [4, 8, 8, 10, 10, 10, 10],
#  'некоторый': [4, 4, 6, 8, 8, 8, 8, 8],
#  'вызывать': [4, 4, 8, 8],
#  'чашечка': [8, 8, 8, 8],
#  'чаша': [8, 8, 8, 8, 10],
#  'широкий': [4, 8, 8, 8, 8, 10],
#  'жаль': [4, 8, 8, 8, 10, 10],
#  'чёрный': [4, 8, 8, 10],
#  'уха': [6, 8, 8, 10],
#  'поэтому': [4, 8, 8, 8, 8, 10],
#  'заменить': [2, 8, 8, 8, 8],
#  'голос': [6, 8, 8, 8, 8, 8, 10, 10, 10],
#  'сильно': [2, 2, 2, 2, 4, 4, 4, 6, 6, 6, 6, 6, 8, 8, 8, 8, 10, 10, 10, 10],
#  'помочь': [6, 6, 6, 8, 8, 10, 10, 10],
#  'басовый': [2, 8, 8, 10, 10, 10],
#  'прийтись': [2, 2, 2, 6, 8, 8, 8, 10, 10],
#  'норма': [2, 2, 4, 6, 10, 10, 10],
#  'абсолютно': [2, 2, 4, 4, 10],
#  'жесть': [2, 2, 6, 6],
#  'оно': [2, 2, 4, 8, 10],
#  'хрипеть': [2, 2, 2, 8],
#  'выполнять': [2, 2, 8, 10, 10, 10],
#  'функция': [2, 2, 6, 6, 6, 8, 10, 10, 10],
#  'понимать': [2, 2, 2, 4, 8],
#  'скайп': [2, 2, 6, 6, 8, 8, 8],
#  'говорить': [2, 2, 2, 6, 8, 8, 10, 10, 10, 10, 10],
#  'позволить': [2, 2, 8, 8],
#  'перестать': [2, 2, 2, 2, 4, 4, 6, 6, 6, 6, 8, 8],
#  'шнур': [2, 2, 2, 2, 4, 6, 6, 8, 8, 8, 10, 10, 10],
#  'отлично': [2, 2, 2, 8, 10, 10, 10, 10, 10, 10, 10, 10],
#  'поначалу': [2, 2, 10, 10],
#  'жать': [2, 2, 6, 10, 10, 10, 10],
#  'минута': [2, 2, 2, 2, 4, 10],
#  'болеть': [2, 2, 4, 4, 6, 6, 6, 8, 8, 8, 10, 10, 10, 10, 10, 10, 10, 10],
#  'решить': [2, 2, 2, 2, 2, 4, 4, 4, 4, 6, 6, 6, 6, 8, 8, 8, 8],
#  'металлический': [2, 2, 8, 8, 10, 10],
#  'душка': [2, 2, 2, 2, 2, 2, 2, 2, 2, 8, 10, 10],
#  'также': [2, 2, 4, 8, 10, 10],
#  'находиться': [2, 2, 4, 6, 10, 10, 10, 10],
#  'начаться': [2, 2, 2, 4, 4],
#  'пропадать': [2, 2, 2, 4, 4, 8],
#  'полтора': [2, 2, 4, 10],
#  'вылезти': [2, 2, 2, 2],
#  'идти': [2, 2, 2, 4, 4, 4, 8, 8, 10, 10],
#  'последний': [2, 2, 6, 8],
#  'обычный': [2, 2, 2, 2, 2, 4, 6, 8],
#  'гарнитур': [2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'замена': [2, 2, 2, 10, 10, 10],
#  'амбошюр': [2, 2, 2, 2],
#  'материал': [2, 2, 6, 6, 6, 10, 10, 10],
#  'долгий': [2, 2, 6, 8, 10],
#  'аккуратно': [2, 2, 10, 10, 10],
#  'стол': [2, 2, 2, 8, 10, 10],
#  'смочь': [2, 2, 4, 8, 10, 10, 10],
#  'длина': [2, 2, 4, 8, 10, 10],
#  'звукоизоляция': [4, 4, 4, 6, 8],
#  'игра': [2,
#   4,
#   4,
#   4,
#   4,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'музыка': [2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   6,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'конструкция': [4, 4, 10, 10, 10],
#  'дужка': [2, 4, 4, 4, 4, 8, 8, 8, 10],
#  'оголовье': [4, 4, 4, 4, 4, 4, 6, 6, 10, 10],
#  'крепиться': [4, 4, 10, 10],
#  'оба': [4, 4, 4, 4, 8, 8],
#  'сторона': [4, 4, 6, 8, 8, 8, 10, 10],
#  'пластика': [4, 4, 4, 4, 8, 10, 10],
#  'лёгкий': [4,
#   4,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'давить': [2,
#   2,
#   4,
#   4,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'ровно': [8, 8, 10, 10],
#  'конец': [4, 8, 8, 8, 8],
#  'второй': [8, 8, 8, 10],
#  'паяльник': [8, 8, 8, 8],
#  'принцип': [8, 8, 10, 10, 10],
#  'диапазон': [6, 8, 8, 10, 10, 10, 10],
#  'воспроизводить': [4, 8, 8, 8],
#  'длительный': [8, 8, 8, 8, 10, 10, 10, 10],
#  'ощущаться': [8, 8, 10, 10],
#  'настройка': [2,
#   4,
#   4,
#   4,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'размер': [4, 8, 8, 10, 10, 10, 10],
#  'регулятор': [2,
#   4,
#   6,
#   6,
#   6,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   8,
#   10,
#   10,
#   10,
#   10,
#   10],
#  'выключатель': [6, 6, 8, 8, 8, 8, 10],
#  'попросту': [4, 8, 8, 10],
#  'дополнительный': [8, 8, 8, 10],
#  'сигнал': [2, 2, 8, 8, 8],
#  'подвести': [10, 10, 10, 10],
#  'правда': [8, 10, 10, 10],
#  'смотреть': [4, 6, 6, 8, 10, 10, 10, 10, 10],
#  'ниже': [4, 6, 6, 8, 10, 10, 10],
#  'посидеть': [6, 10, 10, 10],
#  'начинать': [4, 6, 6, 8, 8, 8, 10, 10, 10, 10, 10, 10, 10],
#  'идеальный': [4, 10, 10, 10, 10],
#  'игровой': [4, 4, 4, 4, 4, 8, 10, 10, 10],
#  'недорогой': [4, 8, 8, 10, 10, 10],
#  'дёшево': [2, 10, 10, 10],
#  'реально': [6, 8, 10, 10],
#  'сделать': [2, 8, 8, 10, 10, 10, 10, 10],
#  'нужно': [4, 6, 6, 6, 6, 8, 8, 8, 8, 10, 10, 10, 10, 10, 10, 10],
#  'лето': [6, 10, 10, 10],
#  'потеть': [2, 2, 4, 6, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10],
#  'приятно': [2, 6, 8, 8, 10, 10, 10],
#  'вещь': [4, 10, 10, 10],
#  'прочный': [8, 10, 10, 10],
#  'крепкий': [10, 10, 10, 10],
#  'разваливаться': [6, 6, 10, 10],
#  'противник': [6, 8, 10, 10, 10, 10],
#  'шаг': [6, 10, 10, 10, 10],
#  'выглядеть': [4, 8, 10, 10, 10, 10, 10, 10, 10, 10],
#  'нормально': [4, 4, 4, 6, 6, 8, 10, 10, 10, 10, 10, 10, 10],
#  'место': [4, 8, 10, 10, 10, 10, 10],
#  'падать': [4, 10, 10, 10],
#  'супер': [10, 10, 10, 10, 10, 10],
#  'выявить': [4, 6, 10, 10, 10],
#  'понравиться': [4, 8, 10, 10],
#  'топ': [10, 10, 10, 10, 10],
#  'сын': [8, 10, 10, 10, 10],
#  'прийти': [2, 2, 2, 4],
#  'поставить': [2, 8, 8, 8],
#  'каждый': [6, 8, 8, 8, 10, 10, 10, 10],
#  'пожалеть': [10, 10, 10, 10],
#  'мягкий': [4, 4, 6, 8, 10, 10, 10, 10, 10, 10, 10],
#  'комп': [2, 4, 4, 4, 4, 10, 10, 10],
#  'сборка': [6, 6, 8, 10, 10, 10, 10, 10, 10],
#  'среднее': [6, 8, 10, 10],
#  'уставать': [2, 10, 10, 10, 10, 10, 10, 10],
#  'покупать': [2, 2, 4, 6, 6, 8, 8, 8, 10, 10, 10, 10, 10, 10],
#  'положение': [2, 2, 10, 10, 10, 10],
#  'кнопка': [2, 8, 8, 10, 10, 10, 10, 10, 10, 10],
#  'писк': [4, 4, 4, 4],
#  'тонкий': [4, 4, 4, 8, 10],
#  'писать': [2, 4, 6, 10, 10, 10, 10, 10],
#  'либо': [2, 4, 4, 4, 4, 10, 10, 10],
#  'тип': [4, 4, 10, 10, 10],
#  'особо': [4, 8, 10, 10],
#  'минус': [4, 4, 10, 10],
#  'подключение': [4, 4, 6, 8, 8, 10, 10, 10, 10],
#  'включить': [2, 4, 4, 4, 8, 8],
#  'становиться': [2, 4, 4, 6, 6, 8],
#  'услышать': [4, 4, 6, 6, 10],
#  'первый': [2, 4, 6, 6, 6, 8, 10, 10, 10, 10, 10, 10, 10],
#  'крайне': [2, 4, 4, 4],
#  'неплохой': [2, 2, 2, 4, 6, 8, 8, 8, 8, 8, 10, 10],
#  'подушка': [6, 6, 6, 8, 10],
#  'плюс': [2, 4, 6, 6, 10, 10, 10, 10, 10, 10, 10, 10],
#  'старый': [2, 6, 6, 10],
#  'нужный': [2, 6, 8, 8, 10, 10, 10, 10],
#  'длинный': [4, 4, 4, 6, 6, 10, 10, 10, 10],
#  'момент': [4, 6, 8, 8],
#  'что-то': [2, 6, 6, 6, 8, 8],
#  'всякий': [4, 8, 8, 10],
#  'маленький': [2, 2, 4, 6, 8, 8, 10, 10, 10],
#  'человек': [2, 4, 8, 8, 10, 10, 10, 10],
#  'хотеться': [4, 6, 8, 8, 10],
#  'дать': [2, 2, 2, 4, 6, 10],
#  'мнение': [6, 6, 6, 10],
#  'сказать': [4, 4, 4, 4, 4, 6, 8, 8, 10, 10, 10, 10],
#  'надёжный': [10, 10, 10, 10],
#  'отвратительный': [2, 2, 2, 2, 2, 2, 4, 4, 6, 10],
#  'хотя': [2, 2, 6, 8, 10],
#  'какой-то': [2, 4, 6, 10],
#  'подобный': [4, 6, 10, 10],
#  'отсутствие': [10, 10, 10, 10, 10],
#  'усилитель': [6, 10, 10, 10],
#  'читать': [6, 10, 10, 10],
#  'думать': [2, 6, 6, 6, 8, 10, 10, 10, 10, 10],
#  'жаловаться': [8, 10, 10, 10],
#  'настроить': [6, 8, 8, 8, 10, 10, 10, 10, 10, 10, 10],
#  'звуковой': [2, 6, 8, 8, 10, 10, 10, 10, 10],
#  'карта': [4, 8, 10, 10, 10, 10, 10],
#  'запись': [2, 8, 10, 10],
#  'слово': [2, 4, 6, 10],
#  'пытаться': [2, 2, 4, 4, 4, 10],
#  'простой': [4, 8, 8, 10],
#  'хотеть': [2, 2, 4, 4, 4, 4, 10, 10],
#  'помощь': [2, 4, 6, 10],
#  'тугой': [4, 4, 4, 4],
#  'сразу': [2, 4, 4, 4, 4, 6, 6, 8, 8, 10, 10, 10],
#  'шумоподавление': [4, 6, 10, 10],
#  'вопрос': [4, 4, 4, 4, 10],
#  'изоляция': [4, 8, 8, 10],
#  'слабый': [2, 6, 6, 8, 8],
#  'подойти': [4, 4, 4, 4, 6, 8, 8, 8, 8, 10],
#  'слышать': [2, 2, 2, 6, 6, 8, 8, 10, 10, 10, 10, 10],
#  'собеседник': [2, 2, 8, 10],
#  'высота': [6, 8, 10, 10],
#  'фильм': [4, 10, 10, 10, 10, 10],
#  'куча': [6, 6, 10, 10],
#  'действительно': [4, 4, 4, 10, 10, 10],
#  'настраивать': [4, 10, 10, 10, 10],
#  'софт': [2, 2, 4, 4, 4, 4, 8, 8],
#  'программа': [6, 8, 8, 8, 10, 10],
#  'пресет': [4, 8, 8, 10],
#  'крутой': [6, 8, 10, 10],
#  'комплект': [4, 4, 4, 6, 8, 10, 10],
#  'съёмный': [4, 6, 10, 10, 10],
#  'знать': [4, 4, 6, 6, 8, 10, 10, 10, 10],
#  'дело': [4, 6, 6, 6, 8, 10, 10, 10, 10],
#  'ощущение': [4, 6, 8, 10],
#  'установить': [2, 8, 8, 10, 10],
#  'драйвер': [2, 8, 10, 10, 10, 10],
#  'сначала': [2, 4, 6, 10, 10],
#  'главное': [4, 6, 10, 10, 10, 10],
#  'шумоизоляция': [4, 6, 10, 10, 10],
#  'позиционирование': [4, 8, 10, 10],
#  'ваш': [4, 4, 4, 4, 10, 10],
#  'обратно': [2, 4, 6, 6, 8],
#  'ибо': [4, 6, 10, 10, 10, 10, 10],
#  'делать': [4, 4, 6, 8, 10],
#  'видео': [4, 6, 8, 10, 10],
#  'дискорд': [8, 10, 10, 10, 10],
#  'шея': [6, 10, 10, 10, 10, 10],
#  'толстый': [4, 6, 8, 10],
#  'искать': [2, 8, 10, 10],
#  'включение': [10, 10, 10, 10],
#  'подсветка': [4, 4, 4, 6, 6, 6, 8, 8, 8, 8, 8, 8, 10, 10, 10, 10, 10, 10, 10],
#  'именно': [4, 4, 8, 10],
#  'неудобный': [2, 2, 4, 6],
#  'смотреться': [6, 8, 10, 10],
#  'снова': [2, 4, 4, 10],
#  'скрежет': [2, 2, 8, 8],
#  'металл': [2, 2, 8, 8],
#  'выходить': [6, 8, 10, 10],
#  'сдать': [2, 4, 4, 6, 6],
#  'выбор': [4, 8, 8, 8, 8],
#  'разочаровать': [2, 2, 2, 8],
#  'оказаться': [2, 2, 2, 4, 10],
#  'технология': [2, 4, 4, 4]}

# %%
def assign_polarity(tokens):
    
    def count_mean(a):
        return round(sum(a)/len(a), 2)
    
    def count_median(a):
        i = int(len(a)//2)
        return a[i] if len(a) % 2 == 1 else count_mean([a[i], a[i-1]])
    
    def count_dispersion(a, mean):
        deviations = []
        for rating in a:
            deviations.append((rating-mean)**2)
        return count_mean(deviations)
    
    markers = {"positive": set(), "negative": set()}
    
    for token in tokens:
        mean = count_mean(tokens[token])
        median = count_median(tokens[token])
        dispersion = count_dispersion(tokens[token], mean)
        
        if dispersion < 3:
            if median >= 9 and len(tokens[token]) > 5:
                markers["positive"].add(token)
            elif median <= 7:
                markers["negative"].add(token)
    
    return markers

markers = assign_polarity(popular_tokens)
markers
# Out:
# {'positive': {'вполне',
#   'выбирать',
#   'диапазон',
#   'длительный',
#   'довольный',
#   'каждый',
#   'настроить',
#   'немного',
#   'особенно',
#   'отличный',
#   'противник',
#   'сборка',
#   'супер',
#   'удобно',
#   'удобство',
#   'чистый',
#   'шея'},
#  'negative': {'амбошюр',
#   'брак',
#   'вылезти',
#   'звукоизоляция',
#   'крайне',
#   'момент',
#   'начаться',
#   'неудобный',
#   'писк',
#   'подушка',
#   'прийти',
#   'сдать',
#   'технология',
#   'тугой'}}

# %%
test_pages = []

for x in "ABCDE":
    with open(f"p{x}.html", "r", encoding="utf-8") as f:
        test_pages.append(f.read())
        
test_reviews = []
for test_page in test_pages:
    test_reviews = extract_data(test_page, test_reviews)

for i in range(len(test_reviews)):
    test_reviews[i] = preedit(test_reviews[i])
    
print(test_reviews)
# Out:
# [{'text': '+ Звук хороший.\n+ Аккуратный дизайн.\n+ Шумодав работает (интересная функция).\n+ Приятная девшука шепчет (Power On, Off и т.д.) при нажатии на кнопку вкл.\n+ Не упадут с ушей, гарантировано.\n- Эти наушники однозначно нацелены на использование для смартфонов, аудио-плееров, авиасамолетов.\n- В комплекте за такую стоимость НЕТ Bluetooth Устройства для PC.\n- Невозможно выключить шумодав вручную без приложения на Android Sony Head....\n- Амбушюры не внушают долгосрочного доверия.\n- Материал обертки ткани и сам ободок, дешевее некуда.\n- Шнур для ПК: это прям максимальная экономия на проводе. 40-60 см т.е. меньше метра. Вам надо сидеть рядом с системником в подмышку его.\n- Шнур для зарядки 7-10 см В КОМПЛЕКТЕ ДАЖЕ ЗАРЯДНИК НЕ ПОЛОЖИЛИ! ЭКОНОМИЯ!\n- Давят зачетно.\n- Не стоят они столько.\nВЫ ТОЛЬКО ПОДУМАЙТЕ!!!! НЕТ УСТРОЙСТВА BLUETOOTH В КОМПЛЕКТЕ!!! ЕГО НЕТ! ПОКУПАТЬ НУЖНО ОТДЕЛЬНО.', 'rating': 6, 'tokens': ['звук', 'хороший', 'аккуратный', 'дизайн', 'шумодать', 'работать', 'интересный', 'функция', 'приятный', 'девшук', 'шептать', 'т.д', 'нажатие', 'кнопка', 'вкл', 'упасть', 'ухо', 'гарантировать', 'наушник', 'однозначно', 'нацелить', 'использование', 'смартфон', 'аудио-плеер', 'авиасамолёт', 'комплект', 'стоимость', 'устройство', 'невозможно', 'выключить', 'шумодать', 'вручную', 'приложение', 'амбушюр', 'внушать', 'долгосрочный', 'доверие', 'материал', 'обёртка', 'ткань', 'ободок', 'дешёвый', 'некуда', 'шнур', 'пк', 'это', 'прям', 'максимальный', 'экономия', 'провод', 'смотреть', 'т.е', 'маленький', 'метр', 'сидеть', 'рядом', 'системник', 'подмышка', 'шнур', 'зарядка', 'смотреть', 'комплект', 'зарядникнуть', 'положить', 'экономия', 'давить', 'зачётный', 'стоять', 'столько', 'подумать', 'устройство', 'комплект', 'покупать', 'нужно', 'отдельно']}, {'text': 'автономность\nшумодав\nзвук\nmultipoint\nНадоели провода, решил купить беспроводные наушники с шумодавом. Выбирал между сони, сенхайзер и ямахой. Sennheiser Momentum 3 отпали из-за низкой автономности ( 17 часов). У ямахи YH-E700A самая высокая автономность (35 ч.), но отзывов по ним почти не было + низкие оценки за мобильное приложение для наушников (якобы вообще никакой функциональности, даже заряд батареи не отображается). В общем выбор пал на сони.\nИспользую только дома: iphone + стационарный ПК c двумя системами (windows + linux). И тут самый главный косяк наушников: multipoint запоминает только 2 устройства, получается что это всегда iphone + одна из систем, в которой я работал последний раз. Если я захожу в другую систему, приходится удалять наушники из списка устройств bluetooth (ОС то их запомнила, но подсоединиться уже не может) и заново спаривать их.\nНу и никакого LDAC кодека, если включен multipoint, только SBC\\AAC, так что аудиофильские наклонности надо поубавить.\nТак же я не нашел, как выставлять режим по умолчанию для наушников, они всегда включаются с активным шумодавом, я бы хотел, чтобы они просто включались в обычном режиме, так что при включении приходится постоянно переключать режим.\nОчень пожалел, что купил их.', 'rating': 4, 'tokens': ['автономность', 'шумодать', 'звук', 'надоесть', 'провод', 'решить', 'купить', 'беспроводный', 'наушник', 'шумодав', 'выбирать', 'соня', 'сенхайзер', 'ямаха', 'отпасть', 'из-за', 'низкий', 'автономность', 'час', 'ямах', 'самый', 'высокий', 'автономность', 'ч', 'отзыв', 'низкий', 'оценка', 'мобильный', 'приложение', 'наушник', 'якобы', 'вообще', 'никакой', 'функциональность', 'заряд', 'батарея', 'отображаться', 'общий', 'выбор', 'пасть', 'соня', 'использовать', 'дом', 'стационарный', 'пк', 'система', 'самый', 'главный', 'косяк', 'наушник', 'запоминать', 'устройство', 'получаться', 'это', 'система', 'который', 'работать', 'последний', 'заходить', 'система', 'приходиться', 'удалять', 'наушник', 'список', 'устройство', 'ос', 'запомнить', 'подсоединиться', 'мочь', 'заново', 'спаривать', 'никакой', 'кодек', 'включить', 'аудиофильский', 'наклонность', 'поубавить', 'найти', 'выставлять', 'режим', 'умолчание', ' ...

# %%
def predict_mood(test_review):
    counter_pos = 0
    counter_neg = 0
    for token in test_review["tokens"]:
        if token in markers["positive"]:
            counter_pos += 1
        elif token in markers["negative"]:
            counter_neg -= 1
    print(test_review['rating'], counter_pos, counter_neg, sep="\t")

for test_review in test_reviews:
    predict_mood(test_review)
# Out:
# 6	0	0
# 4	1	0
# 10	2	0
# 6	0	0
# 10	1	-1
# 10	0	0
# 10	0	0
# 10	0	0
# 10	1	0
# 8	0	0
# 10	1	0
# 6	1	-2
# 10	2	0
# 10	0	0
# 8	0	-1
# 10	1	0
# 10	2	0
# 10	2	0
# 6	2	0
# 10	0	0
# 10	1	0
# 10	1	0
# 10	2	0
# 6	0	0
# 4	0	0
# 10	0	0
# 4	0	0
# 8	1	0
# 6	0	0
# 2	1	0
# 8	2	0
# 8	0	0
# 6	1	0
# 8	0	0
# 8	0	0
# 10	0	0
# 8	1	0
# 8	0	-1
# 10	0	0
# 8	2	0
# 8	0	0
# 2	1	0
# 8	0	0
# 10	3	0
# 10	0	0
# 10	0	0
# 4	0	-1
# 10	0	0
# 8	1	0
# 2	0	0
# 6	0	0
# 4	3	-1
# 8	1	-3
# 8	1	0
# 6	1	-1
